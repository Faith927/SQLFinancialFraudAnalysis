# %%
import pymysql
import pandas as pd

# %%
db_name = "fraudanalysis"
db_host = "127.0.0.1"
db_username = "root"
db_password = "******"

try:
    conn = pymysql.connect(host = db_host,
                           port = int(3306),
                           user = "root",
                           password = db_password,
                           db = db_name)
except e:
    print (e)
if conn:
    print ("connection successful")
else:
        print ("error")
# Out:
# connection successful

# %%
with conn.cursor() as cursor:
    cursor.execute("SELECT * FROM account_activity")
    results = cursor.fetchall()
    for row in results:
        print(row)
# Out:
# (1001, 9507.27205955636, '2022-01-01')
# (1002, 7408.704535557173, '2022-01-02')
# (1003, 1715.321988918382, '2022-01-03')
# (1004, 3101.5091338402535, '2022-01-04')
# (1005, 5405.766913696731, '2022-01-05')
# (1006, 9347.967162033714, '2022-01-06')
# (1007, 2957.7600542968958, '2022-01-07')
# (1008, 8303.773585052018, '2022-01-08')
# (1009, 5359.747810190935, '2022-01-09')
# (1010, 9506.882688627556, '2022-01-10')
# (1011, 1895.7059030143778, '2022-01-11')
# (1012, 2706.148887561668, '2022-01-12')
# (1013, 8646.50724993274, '2022-01-13')
# (1014, 9922.291973047819, '2022-01-14')
# (1015, 3146.2481883176556, '2022-01-15')
# (1016, 8612.857297188031, '2022-01-16')
# (1017, 5179.000965050205, '2022-01-17')
# (1018, 2727.8305249244922, '2022-01-18')
# (1019, 3797.7345359806613, '2022-01-19')
# (1020, 3552.8551470813677, '2022-01-20')
# (1021, 8552.672866957477, '2022-01-21')
# (1022, 4265.273573478986, '2022-01-22')
# (1023, 9545.474869076339, '2022-01-23')
# ...
